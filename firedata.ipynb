# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Fireball Data

# %%
fire_df = pd.read_csv("D:/UNC Charlotte Fall 2022/Capstone Class/cneos_fireball_data.csv")

# %% [markdown]
# ## Data Understanding

# %%
fire_df.head()
# Out:
#   Peak Brightness Date/Time (UT) Latitude (deg.) Longitude (deg.)  \
# 0            2022-10-28 17:40:11            7.1N           118.9W
# 1            2022-10-20 20:55:07           26.6N           165.1E
# 2            2022-09-15 02:49:02           22.7N            97.6E
# 3            2022-09-14 23:31:15           40.8N            63.4E
# 4            2022-09-04 03:54:55           20.0N           165.9E
#
#    Altitude (km)  Velocity (km/s)    vx    vy   vz  Total Radiated Energy (J)  \
# 0           45.0              NaN   NaN   NaN  NaN               4.700000e+10
# 1           65.6              NaN   NaN   NaN  NaN               4.700000e+10
# 2           31.5              NaN   NaN   NaN  NaN               2.700000e+10
# 3           35.8             17.4 -13.9  -4.3  9.5               3.200000e+10
# 4           14.0             21.9  18.4 -11.4 -3.5               2.400000e+10
#
#    Calculated Total Impact Energy (kt)
# 0                                0.160
# ...

# %%
fire_df.columns
# Out:
# Index(['Peak Brightness Date/Time (UT)', 'Latitude (deg.)', 'Longitude (deg.)',
#        'Altitude (km)', 'Velocity (km/s)', 'vx', 'vy', 'vz',
#        'Total Radiated Energy (J)', 'Calculated Total Impact Energy (kt)'],
#       dtype='object')

# %%
fire_df.isna().sum()
#quite a bit of null values.
# Out:
# Peak Brightness Date/Time (UT)           0
# Latitude (deg.)                        190
# Longitude (deg.)                       190
# Altitude (km)                          458
# Velocity (km/s)                        654
# vx                                     654
# vy                                     654
# vz                                     654
# Total Radiated Energy (J)                0
# Calculated Total Impact Energy (kt)      0
# dtype: int64

# %%
fire_df.shape
# Out:
# (932, 10)

# %%
sns.pairplot(fire_df)

# %%
sns.scatterplot( data=fire_df, x='Calculated Total Impact Energy (kt)', y='Total Radiated Energy (J)')
# Out:
# <AxesSubplot:xlabel='Calculated Total Impact Energy (kt)', ylabel='Total Radiated Energy (J)'>

# %%
fire_df.dtypes
# Out:
# Peak Brightness Date/Time (UT)          object
# Latitude (deg.)                         object
# Longitude (deg.)                        object
# Altitude (km)                          float64
# Velocity (km/s)                        float64
# vx                                     float64
# vy                                     float64
# vz                                     float64
# Total Radiated Energy (J)              float64
# Calculated Total Impact Energy (kt)    float64
# dtype: object

# %%
fire_df['Date'] = pd.to_datetime(fire_df['Peak Brightness Date/Time (UT)']).dt.date
fire_df['Time'] = pd.to_datetime(fire_df['Peak Brightness Date/Time (UT)']).dt.time

# %%
fire_df.head()
# Out:
#   Peak Brightness Date/Time (UT) Latitude (deg.) Longitude (deg.)  \
# 0            2022-10-28 17:40:11            7.1N           118.9W
# 1            2022-10-20 20:55:07           26.6N           165.1E
# 2            2022-09-15 02:49:02           22.7N            97.6E
# 3            2022-09-14 23:31:15           40.8N            63.4E
# 4            2022-09-04 03:54:55           20.0N           165.9E
#
#    Altitude (km)  Velocity (km/s)    vx    vy   vz  Total Radiated Energy (J)  \
# 0           45.0              NaN   NaN   NaN  NaN               4.700000e+10
# 1           65.6              NaN   NaN   NaN  NaN               4.700000e+10
# 2           31.5              NaN   NaN   NaN  NaN               2.700000e+10
# 3           35.8             17.4 -13.9  -4.3  9.5               3.200000e+10
# 4           14.0             21.9  18.4 -11.4 -3.5               2.400000e+10
#
#    Calculated Total Impact Energy (kt)        Date      Time
# ...

# %%
fire_df.dtypes
#need to convert Date to date object.
#then create a feature for year using that date object
# Out:
# Peak Brightness Date/Time (UT)          object
# Latitude (deg.)                         object
# Longitude (deg.)                        object
# Altitude (km)                          float64
# Velocity (km/s)                        float64
# vx                                     float64
# vy                                     float64
# vz                                     float64
# Total Radiated Energy (J)              float64
# Calculated Total Impact Energy (kt)    float64
# Date                                    object
# Time                                    object
# dtype: object

# %%
fire_df['Date'] = pd.to_datetime(fire_df['Date'])

# %%
fire_df.dtypes
# Out:
# Peak Brightness Date/Time (UT)                 object
# Latitude (deg.)                                object
# Longitude (deg.)                               object
# Altitude (km)                                 float64
# Velocity (km/s)                               float64
# vx                                            float64
# vy                                            float64
# vz                                            float64
# Total Radiated Energy (J)                     float64
# Calculated Total Impact Energy (kt)           float64
# Date                                   datetime64[ns]
# Time                                           object
# dtype: object

# %%
fire_df['Year'] = fire_df['Date'].dt.year
fire_df['Month'] = fire_df['Date'].dt.month_name()

# %%
fire_df.head()
# Out:
#   Peak Brightness Date/Time (UT) Latitude (deg.) Longitude (deg.)  \
# 0            2022-10-28 17:40:11            7.1N           118.9W
# 1            2022-10-20 20:55:07           26.6N           165.1E
# 2            2022-09-15 02:49:02           22.7N            97.6E
# 3            2022-09-14 23:31:15           40.8N            63.4E
# 4            2022-09-04 03:54:55           20.0N           165.9E
#
#    Altitude (km)  Velocity (km/s)    vx    vy   vz  Total Radiated Energy (J)  \
# 0           45.0              NaN   NaN   NaN  NaN               4.700000e+10
# 1           65.6              NaN   NaN   NaN  NaN               4.700000e+10
# 2           31.5              NaN   NaN   NaN  NaN               2.700000e+10
# 3           35.8             17.4 -13.9  -4.3  9.5               3.200000e+10
# 4           14.0             21.9  18.4 -11.4 -3.5               2.400000e+10
#
#    Calculated Total Impact Energy (kt)       Date      Time  Year      Month
# ...

# %%
fire_df['Year'].hist(bins=30, figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
sns.set(rc={"figure.figsize":(20,12)})
ax = sns.countplot(fire_df['Year'])
plt.ticklabel_format(style='plain', axis='y')
ax= plt.gca()
ax.set_title("Number of Fireball Events per Year")
# Out:
# c:\Users\agpju\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Number of Fireball Events per Year')

# %%
df_2020 = fire_df[fire_df['Year'] == 2020]
#dataframe for fireballs in 2020

# %%
df_2020.iloc[0]
# Out:
# Peak Brightness Date/Time (UT)         2020-12-29 20:32:22
# Latitude (deg.)                                      14.9N
# Longitude (deg.)                                    158.2W
# Altitude (km)                                         33.0
# Velocity (km/s)                                       14.4
# vx                                                    -3.0
# vy                                                    10.2
# vz                                                    -9.7
# Total Radiated Energy (J)                    49000000000.0
# Calculated Total Impact Energy (kt)                   0.16
# Date                                   2020-12-29 00:00:00
# Time                                              20:32:22
# Year                                                  2020
# Month                                             December
# Name: 68, dtype: object

# %%
month_names = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# %%
sns.set(rc={"figure.figsize":(12,6)})
ax = sns.countplot(df_2020['Month'], order=month_names)
plt.ticklabel_format(style='plain', axis='y')
ax=plt.gca()
ax.set_title("Number of Fireballs by Month in 2020")
# Out:
# c:\Users\agpju\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Number of Fireballs by Month in 2020')

# %%
fire_df['Year'].unique()
# Out:
# array([2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012,
#        2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001,
#        2000, 1999, 1998, 1997, 1996, 1995, 1994, 1993, 1991, 1990, 1988],
#       dtype=int64)

# %%
#dataframes for each year, 1988-2022
df_1988 = fire_df[fire_df['Year'] == 1988]
df_1990 = fire_df[fire_df['Year'] == 1990]
df_1991 = fire_df[fire_df['Year'] == 1991]
df_1993 = fire_df[fire_df['Year'] == 1993]
df_1994 = fire_df[fire_df['Year'] == 1994]
df_1995 = fire_df[fire_df['Year'] == 1995]
df_1996 = fire_df[fire_df['Year'] == 1996]
df_1997 = fire_df[fire_df['Year'] == 1997]
df_1998 = fire_df[fire_df['Year'] == 1998]
df_1999 = fire_df[fire_df['Year'] == 1999]
df_2000 = fire_df[fire_df['Year'] == 2000]
df_2001 = fire_df[fire_df['Year'] == 2001]
df_2002 = fire_df[fire_df['Year'] == 2002]
df_2003 = fire_df[fire_df['Year'] == 2003]
df_2004 = fire_df[fire_df['Year'] == 2004]
df_2005 = fire_df[fire_df['Year'] == 2005]
df_2006 = fire_df[fire_df['Year'] == 2006]
df_2007 = fire_df[fire_df['Year'] == 2007]
df_2008 = fire_df[fire_df['Year'] == 2008]
df_2009 = fire_df[fire_df['Year'] == 2009]
df_2010 = fire_df[fire_df['Year'] == 2010]
df_2011 = fire_df[fire_df['Year'] == 2011]
df_2012 = fire_df[fire_df['Year'] == 2012]
df_2013 = fire_df[fire_df['Year'] == 2013]
df_2014 = fire_df[fire_df['Year'] == 2014]
df_2015 = fire_df[fire_df['Year'] == 2015]
df_2016 = fire_df[fire_df['Year'] == 2016]
df_2017 = fire_df[fire_df['Year'] == 2017]
df_2018 = fire_df[fire_df['Year'] == 2018]
df_2019 = fire_df[fire_df['Year'] == 2019]
df_2020 = fire_df[fire_df['Year'] == 2020]
df_2021 = fire_df[fire_df['Year'] == 2021]
df_2022 = fire_df[fire_df['Year'] == 2022]

# %%
sns.set(rc={"figure.figsize":(12,6)})
ax = sns.countplot(df_1988['Month'], order=month_names)
plt.ticklabel_format(style='plain', axis='y')
ax=plt.gca()
ax.set_title("Number of Fireballs by Month in 1988")
# Out:
# c:\Users\agpju\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Number of Fireballs by Month in 1988')

# %%
sns.set(rc={"figure.figsize":(12,6)})
ax = sns.countplot(df_2022['Month'], order=month_names)
plt.ticklabel_format(style='plain', axis='y')
ax=plt.gca()
ax.set_title("Number of Fireballs by Month in 2022")
# Out:
# c:\Users\agpju\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Number of Fireballs by Month in 2022')

# %%
sns.set(rc={"figure.figsize":(12,6)})
ax = sns.countplot(df_2021['Month'], order=month_names)
plt.ticklabel_format(style='plain', axis='y')
ax=plt.gca()
ax.set_title("Number of Fireballs by Month in 2021")
# Out:
# c:\Users\agpju\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Number of Fireballs by Month in 2021')

# %%
sns.set(rc={"figure.figsize":(12,6)})
ax = sns.countplot(fire_df['Month'], order=month_names)
plt.ticklabel_format(style='plain', axis='y')
ax=plt.gca()
ax.set_title("Number of Fireballs by Month in 1988-2022")
# Out:
# c:\Users\agpju\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Number of Fireballs by Month in 1988-2022')

# %%
sns.set(rc={"figure.figsize":(12,6)})
ax = sns.regplot(data=df_2021, x='Altitude (km)', y='Velocity (km/s)')
plt.ticklabel_format(style='plain', axis='y')
ax=plt.gca()
ax.set_title("Regression plot of 2021 velocity/altitude")
# Out:
# Text(0.5, 1.0, 'Regression plot of 2021 velocity/altitude')

# %%
sns.set(rc={"figure.figsize":(12,6)})
ax = sns.regplot(data=df_2022, x='Altitude (km)', y='Velocity (km/s)')
plt.ticklabel_format(style='plain', axis='y')
ax=plt.gca()
ax.set_title("Regression plot of 2022 velocity/altitude")
# Out:
# Text(0.5, 1.0, 'Regression plot of 2022 velocity/altitude')

# %%
#number of fireballs in 2019
df_2017['Year'].count()
# Out:
# 29

# %%
#Save the dataframe into a new csv file
fire_df.to_csv('fire_df.csv', header=True)
